# %%
import numpy as np
import pandas
import cv2 
from matplotlib import pyplot as plt

# %%
img_a=cv2.imread('center.jpeg')
temp_a=cv2.cvtColor(img_a,cv2.COLOR_BGR2RGB)
plt.imshow(temp_b)
temp1_a=cv2.resize(temp_a,(120,120))
bordersize = 10
border_a = cv2.copyMakeBorder(
    temp1_a,
    top=bordersize,
    bottom=bordersize,
    left=bordersize,
    right=bordersize,
    borderType=cv2.BORDER_CONSTANT
)

plt.imshow(border_a)

# %%
img_b=cv2.imread('top_left.jpg')
temp_b=cv2.cvtColor(img_b,cv2.COLOR_BGR2RGB)
plt.imshow(temp_b)
temp1_b=cv2.resize(temp_b,(200,200))
bordersize = 10
border_b = cv2.copyMakeBorder(
    temp1_b,
    top=bordersize,
    bottom=bordersize,
    left=bordersize,
    right=bordersize,
    borderType=cv2.BORDER_CONSTANT
)

plt.imshow(border_b)

# %%
img_c=cv2.imread('top_right.jpg')
temp_c=cv2.cvtColor(img_c,cv2.COLOR_BGR2RGB)
plt.imshow(temp_c)
temp1_c=cv2.resize(temp_c,(200,200))
bordersize = 10
border_c = cv2.copyMakeBorder(
    temp1_c,
    top=bordersize,
    bottom=bordersize,
    left=bordersize,
    right=bordersize,
    borderType=cv2.BORDER_CONSTANT
)

plt.imshow(border_c)

# %%
img_d=cv2.imread('bottom_left.jpg')
temp_d=cv2.cvtColor(img_d,cv2.COLOR_BGR2RGB)
plt.imshow(temp_d)
temp1_d=cv2.resize(temp_d,(200,200))
bordersize = 10
border_d = cv2.copyMakeBorder(
    temp1_d,
    top=bordersize,
    bottom=bordersize,
    left=bordersize,
    right=bordersize,
    borderType=cv2.BORDER_CONSTANT
)

plt.imshow(border_d)

# %%
img_e=cv2.imread('bottom_right.jpg')
temp_e=cv2.cvtColor(img_e,cv2.COLOR_BGR2RGB)
plt.imshow(temp_e)
temp1_e=cv2.resize(temp_e,(200,200))
bordersize = 10
border_e = cv2.copyMakeBorder(
    temp1_e,
    top=bordersize,
    bottom=bordersize,
    left=bordersize,
    right=bordersize,
    borderType=cv2.BORDER_CONSTANT
)

plt.imshow(border_e)

# %%
def create_blank_black_canvas(width, height):
    image = np.zeros((height, width, 3),np.uint8)
    return image

# %%
canvas = create_blank_black_canvas(430, 430)

# %%
plt.imshow(canvas)
canvas.shape
# Out:
# (430, 430, 3)

# %%
temp1_a.shape
# Out:
# (200, 200, 3)

# %%
canvas[10:210,10:210,:] = temp1_b
canvas[10:210,220:420,:] = temp1_c
canvas[220:420,10:210,:] = temp1_d
canvas[220:420,220:420,:] = temp1_e
canvas[145:285,145:285,:] = border_a
plt.imshow(canvas)
